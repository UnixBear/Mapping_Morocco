# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import data
df = pd.read_excel("../../../Downloads/indicateurs-macroeco-revenu-national-brute_2010-2020.xlsx")
df.head(10)
# Out:
#                                           Unnamed: 0           Unnamed: 1  \
# 0                      Indicateurs macro-économiques                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN  1905-06-18 00:00:00
# 3  Revenu national brut disponible aux prix coura...                  NaN
# 4                                         Ressources                  NaN
# 5                               Revenu national brut                  NaN
# 6                                                PIB                  NaN
# 7  Revenu de la propriété net en provenance de l'...                  NaN
# 8  Transferts courants nets en provenance de l'ex...                  NaN
# 9                                            Emplois                  NaN
#
#       Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# ...
