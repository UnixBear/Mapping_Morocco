# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import data
df = pd.read_csv("../API_MAR_DS2_en_csv_v3_4512242.csv")
df.head()
# Out:
#   Country Name Country Code  \
# 0      Morocco          MAR
# 1      Morocco          MAR
# 2      Morocco          MAR
# 3      Morocco          MAR
# 4      Morocco          MAR
#
#                                       Indicator Name     Indicator Code  \
# 0  Merchandise exports to low- and middle-income ...  TX.VAL.MRCH.WR.ZS
# 1       ICT goods exports (% of total goods exports)  TX.VAL.ICTG.ZS.UN
# 2  Merchandise imports from low- and middle-incom...  TM.VAL.MRCH.R6.ZS
# 3  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 4          Bound rate, simple mean, all products (%)  TM.TAX.MRCH.BR.ZS
#
#        1960      1961      1962      1963      1964      1965  ...      2013  \
# 0  8.529997  6.409131  5.159420  3.758213  2.372645  3.056463  ...  3.289602
# 1       NaN       NaN       NaN       NaN       NaN       NaN  ...  2.867267
# 2  1.760822  1.348315  2.162162  1.935778  2.557377  2.334890  ...  0.745685
# ...
